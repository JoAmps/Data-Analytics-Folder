# %%
#import the neccesary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)

# %%
data=pd.read_csv('data_new')

# %%
weather=pd.read_csv('weather_new')

# %%
building=pd.read_csv('building_new')

# %% [markdown]
# ### Data types and duplicate values

# %%
weather.head(3)
# Out:
#    Unnamed: 0  site_id            timestamp  air_temperature  cloud_coverage  \
# 0           0        0  2016-01-01 00:00:00             25.0             6.0
# 1           1        0  2016-01-01 01:00:00             24.4             4.0
# 2           2        0  2016-01-01 02:00:00             22.8             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             20.0                0.0              1019.7             0.0
# 1             21.1               -1.0              1020.2            70.0
# 2             21.1                0.0              1020.2             0.0
#
#    wind_speed
# 0         0.0
# 1         1.5
# 2         0.0

# %%
weather.dtypes
# Out:
# Unnamed: 0              int64
# site_id                 int64
# timestamp              object
# air_temperature       float64
# cloud_coverage        float64
# dew_temperature       float64
# precip_depth_1_hr     float64
# sea_level_pressure    float64
# wind_direction        float64
# wind_speed            float64
# dtype: object

# %% [markdown]
# ##### timestamp column is wrong and has to be dealth with

# %%
weather['timestamp']=pd.to_datetime(weather['timestamp'])

# %%
#timestamp column datatype is now fixed
weather.dtypes
# Out:
# Unnamed: 0                     int64
# site_id                        int64
# timestamp             datetime64[ns]
# air_temperature              float64
# cloud_coverage               float64
# dew_temperature              float64
# precip_depth_1_hr            float64
# sea_level_pressure           float64
# wind_direction               float64
# wind_speed                   float64
# dtype: object

# %% [markdown]
# #### Here too,the timestamp column has a lot of duplicates values, they need to be taken care of

# %%
weather['timestamp'].duplicated().sum()
# Out:
# 130609

# %%
weather['timestamp'].drop_duplicates(inplace=True)

# %%
weather=weather.dropna(subset=['timestamp'])

# %%
weather.shape
# Out:
# (139393, 10)

# %%
data.head()
# Out:
#    Unnamed: 0  building_id  meter            timestamp  meter_reading
# 0           0            0      0  2016-01-01 00:00:00            0.0
# 1           1            1      0  2016-01-01 00:00:00            0.0
# 2           2            2      0  2016-01-01 00:00:00            0.0
# 3           3            3      0  2016-01-01 00:00:00            0.0
# 4           4            4      0  2016-01-01 00:00:00            0.0

# %%
data['meter'].value_counts()
# Out:
# 0    12060910
# 1     4182440
# 2     2708713
# 3     1264037
# Name: meter, dtype: int64

# %%
data['timestamp'].value_counts()
# Out:
# 2016-12-27 22:00:00    2370
# 2016-12-27 19:00:00    2369
# 2016-12-27 17:00:00    2369
# 2016-12-27 20:00:00    2369
# 2016-12-27 21:00:00    2369
# 2016-12-18 14:00:00    2368
# 2016-12-15 00:00:00    2368
# 2016-12-27 23:00:00    2368
# 2016-12-28 02:00:00    2368
# 2016-12-28 00:00:00    2368
# 2016-12-28 01:00:00    2368
# 2016-12-12 21:00:00    2368
# 2016-12-09 23:00:00    2367
# 2016-12-07 22:00:00    2367
# 2016-12-15 17:00:00    2367
# 2016-12-12 20:00:00    2367
# 2016-12-27 14:00:00    2367
# 2016-12-18 17:00:00    2367
# 2016-12-13 17:00:00    2367
# 2016-12-18 13:00:00    2367
# 2016-12-18 16:00:00    2367
# 2016-12-12 22:00:00    2367
# 2016-12-14 05:00:00    2367
# 2016-12-15 11:00:00    2367
# 2016-12-18 20:00:00    2367
# 2016-12-27 18:00:00    2367
# 2016-12-13 19:00:00    2367
# 2016-12-31 20:00:00    2366
# 2016-12-27 16:00:00    2366
# 2016-12-15 07:00:00    2366
# 2016-12-22 21:00:00    2366
# 2016-12-12 23:00:00    2366
# 2016-12-18 10:00:00    2366
# ...

# %% [markdown]
# ##### Here too,the timestamp column has a lot of duplicates values, they need to be taken care of

# %%
data['timestamp']=data['timestamp'].drop_duplicates(keep='last')

# %%
data=data.dropna(subset=['timestamp'])

# %%
data.shape
# Out:
# (8784, 5)

# %%
data.head()
# Out:
#        Unnamed: 0  building_id  meter            timestamp  meter_reading
# 2300         2300         1448      0  2016-01-01 00:00:00          2.325
# 4593         4593         1448      0  2016-01-01 01:00:00          2.225
# 6892         6892         1448      0  2016-01-01 02:00:00          2.275
# 9188         9188         1448      0  2016-01-01 03:00:00          2.575
# 11484       11484         1448      0  2016-01-01 04:00:00          3.075

# %%
data['timestamp']=pd.to_datetime(data['timestamp'])

# %%
data.dtypes
# Out:
# Unnamed: 0                int64
# building_id               int64
# meter                     int64
# timestamp        datetime64[ns]
# meter_reading           float64
# dtype: object

# %%
building.head()
# Out:
#    Unnamed: 0  site_id  building_id primary_use  square_feet  year_built
# 0           0        0            0   Education         7432      2008.0
# 1           1        0            1   Education         2720      2004.0
# 2           2        0            2   Education         5376      1991.0
# 3           3        0            3   Education        23685      2002.0
# 4           4        0            4   Education       116607      1975.0

# %%
building.dtypes
# Out:
# Unnamed: 0       int64
# site_id          int64
# building_id      int64
# primary_use     object
# square_feet      int64
# year_built     float64
# dtype: object

# %%
building.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### the data types and duplicate values are taken care of

# %%
print(data.shape)
print(weather.shape)
print(building.shape)
# Out:
# (8784, 5)
# (139393, 10)
# (1449, 6)

# %%
building.head()
# Out:
#    Unnamed: 0  site_id  building_id primary_use  square_feet  year_built
# 0           0        0            0   Education         7432      2008.0
# 1           1        0            1   Education         2720      2004.0
# 2           2        0            2   Education         5376      1991.0
# 3           3        0            3   Education        23685      2002.0
# 4           4        0            4   Education       116607      1975.0

# %%
#dropping of an unneccesary column
data.drop(columns='Unnamed: 0',inplace=True)
building.drop(columns='Unnamed: 0',inplace=True)
weather.drop(columns='Unnamed: 0',inplace=True)

# %%
weather.head()
# Out:
#    site_id           timestamp  air_temperature  cloud_coverage  \
# 0        0 2016-01-01 00:00:00             25.0             6.0
# 1        0 2016-01-01 01:00:00             24.4             4.0
# 2        0 2016-01-01 02:00:00             22.8             2.0
# 3        0 2016-01-01 03:00:00             21.1             2.0
# 4        0 2016-01-01 04:00:00             20.0             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             20.0                0.0              1019.7             0.0
# 1             21.1               -1.0              1020.2            70.0
# 2             21.1                0.0              1020.2             0.0
# 3             20.6                0.0              1020.1             0.0
# 4             20.0               -1.0              1020.0           250.0
#
#    wind_speed
# 0         0.0
# 1         1.5
# 2         0.0
# 3         0.0
# 4         2.6

# %% [markdown]
# #### The weather data and the data 'data' can be combined using the timestamp as the common variable,

# %%
weather.isnull().sum()
# Out:
# site_id               0
# timestamp             0
# air_temperature       0
# cloud_coverage        0
# dew_temperature       0
# precip_depth_1_hr     0
# sea_level_pressure    0
# wind_direction        0
# wind_speed            0
# dtype: int64

# %%
new_data=data.merge(weather, on='timestamp', how='outer')

# %%
data.isnull().sum()
# Out:
# building_id      0
# meter            0
# timestamp        0
# meter_reading    0
# dtype: int64

# %%
data['timestamp'].value_counts()
# Out:
# 2016-04-19 12:00:00    1
# 2016-07-05 07:00:00    1
# 2016-10-22 07:00:00    1
# 2016-12-06 15:00:00    1
# 2016-05-01 20:00:00    1
# 2016-03-18 11:00:00    1
# 2016-06-23 03:00:00    1
# 2016-05-23 23:00:00    1
# 2016-03-27 10:00:00    1
# 2016-01-15 18:00:00    1
# 2016-04-30 00:00:00    1
# 2016-06-10 19:00:00    1
# 2016-09-02 05:00:00    1
# 2016-04-05 09:00:00    1
# 2016-06-06 19:00:00    1
# 2016-05-15 22:00:00    1
# 2016-03-09 12:00:00    1
# 2016-10-05 21:00:00    1
# 2016-10-07 00:00:00    1
# 2016-12-08 10:00:00    1
# 2016-10-04 21:00:00    1
# 2016-02-29 13:00:00    1
# 2016-08-05 14:00:00    1
# 2016-02-20 14:00:00    1
# 2016-07-28 10:00:00    1
# 2016-02-11 15:00:00    1
# 2016-11-06 17:00:00    1
# 2016-02-02 16:00:00    1
# 2016-11-11 22:00:00    1
# 2016-04-16 03:00:00    1
# 2016-01-24 17:00:00    1
# 2016-12-13 12:00:00    1
# 2016-08-06 10:00:00    1
# 2016-10-09 20:00:00    1
# 2016-09-01 10:00:00    1
# 2016-01-01 02:00:00    1
# 2016-06-01 22:00:00    1
# ...

# %%
new_data1=new_data.merge(building, on='building_id', how='outer')

# %%
print(new_data1.shape)
# Out:
# (140836, 16)

# %% [markdown]
# #### the building data can be combined with the data already combined using the building id

# %%
#new_data1=data.merge(building, on='building_id', how='outer')

# %%
new_data1.shape
# Out:
# (140836, 16)

# %%
new_data1.head()
# Out:
#    building_id  meter  timestamp  meter_reading  site_id_x  air_temperature  \
# 0         1448    0.0 2016-01-01          2.325        0.0             25.0
# 1         1448    0.0 2016-01-01          2.325        1.0              3.8
# 2         1448    0.0 2016-01-01          2.325        2.0             15.6
# 3         1448    0.0 2016-01-01          2.325        3.0             10.0
# 4         1448    0.0 2016-01-01          2.325        7.0             -1.8
#
#    cloud_coverage  dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# 0        6.000000             20.0           0.000000              1019.7
# 1        0.571429              2.4           0.000000              1020.9
# 2        6.000000             -5.6           0.000000              1015.3
# 3        8.000000              2.2           0.000000              1021.1
# 4        0.002792             -3.2           0.555556              1016.0
#
# ...

# %%
new_data1['primary_use'].value_counts()
# Out:
# Office                           118599
# Lodging/residential               19242
# Entertainment/public assembly      2156
# Education                           549
# Public services                     156
# Other                                25
# Healthcare                           23
# Parking                              22
# Warehouse/storage                    13
# Manufacturing/industrial             12
# Retail                               11
# Services                             10
# Technology/science                    6
# Food sales and service                5
# Utility                               4
# Religious worship                     3
# Name: primary_use, dtype: int64

# %%
new_data1.isnull().sum()
# Out:
# building_id              0
# meter                 1443
# timestamp             1443
# meter_reading         1443
# site_id_x             1443
# air_temperature       1443
# cloud_coverage        1443
# dew_temperature       1443
# precip_depth_1_hr     1443
# sea_level_pressure    1443
# wind_direction        1443
# wind_speed            1443
# site_id_y                0
# primary_use              0
# square_feet              0
# year_built               0
# dtype: int64

# %%
#dropping the missing values
new_data1=new_data1.interpolate()

# %%
new_data1.head()
# Out:
#    building_id  meter  timestamp  meter_reading  site_id_x  air_temperature  \
# 0         1448    0.0 2016-01-01          2.325        0.0             25.0
# 1         1448    0.0 2016-01-01          2.325        1.0              3.8
# 2         1448    0.0 2016-01-01          2.325        2.0             15.6
# 3         1448    0.0 2016-01-01          2.325        3.0             10.0
# 4         1448    0.0 2016-01-01          2.325        7.0             -1.8
#
#    cloud_coverage  dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# 0        6.000000             20.0           0.000000              1019.7
# 1        0.571429              2.4           0.000000              1020.9
# 2        6.000000             -5.6           0.000000              1015.3
# 3        8.000000              2.2           0.000000              1021.1
# 4        0.002792             -3.2           0.555556              1016.0
#
# ...

# %%
new_data1.shape
# Out:
# (140836, 16)

# %%
new_data1=new_data1.dropna()

# %%
new_data1['meter_reading'].value_counts()
# Out:
# 0.0000      2606
# 2.8750      1576
# 3.1000      1475
# 2.8250      1430
# 3.1500      1412
# 2.8000      1412
# 2.8500      1412
# 3.1250      1403
# 2.9000      1389
# 3.1750      1386
# 2.7250      1385
# 3.0750      1380
# 3.0500      1368
# 2.9500      1367
# 2.5750      1360
# 2.7750      1334
# 3.0250      1333
# 2.6250      1322
# 2.9750      1303
# 3.2000      1299
# 2.6750      1290
# 2.7500      1287
# 2.9250      1276
# 3.0000      1269
# 3.4750      1247
# 2.6500      1240
# 3.4000      1225
# 3.2250      1211
# 3.2750      1208
# 3.2500      1193
# 2.5500      1192
# 2.7000      1192
# 3.6250      1146
# 3.3250      1143
# 3.4500      1142
# 3.7250      1140
# 3.3750      1131
# 3.8750      1127
# 2.6000      1097
# 3.7000      1081
# 3.5000      1074
# 2.5000      1066
# 3.5500      1054
# 2.5250      1049
# 3.8500      1044
# 3.4250      1042
# 3.9500      1035
# 2.4750      1033
# 2.4500      1032
# 4.2750      1032
# 2.3750      1019
# 2.4250      1018
# ...

# %%
#creating a copy
data=new_data1.copy()

# %%
data.head()
# Out:
#    building_id  meter  timestamp  meter_reading  site_id_x  air_temperature  \
# 0         1448    0.0 2016-01-01          2.325        0.0             25.0
# 1         1448    0.0 2016-01-01          2.325        1.0              3.8
# 2         1448    0.0 2016-01-01          2.325        2.0             15.6
# 3         1448    0.0 2016-01-01          2.325        3.0             10.0
# 4         1448    0.0 2016-01-01          2.325        7.0             -1.8
#
#    cloud_coverage  dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# 0        6.000000             20.0           0.000000              1019.7
# 1        0.571429              2.4           0.000000              1020.9
# 2        6.000000             -5.6           0.000000              1015.3
# 3        8.000000              2.2           0.000000              1021.1
# 4        0.002792             -3.2           0.555556              1016.0
#
# ...

# %%
data.shape
# Out:
# (139393, 16)

# %%
#dropping more unneccesary columns
data=data.drop(columns=['site_id_x','site_id_y','building_id','year_built'])

# %%
data.shape
# Out:
# (139393, 12)

# %% [markdown]
# ## Looks like all the data cleaning has been done, all columns looking good

# %%
data.to_csv('clean_data.csv')
